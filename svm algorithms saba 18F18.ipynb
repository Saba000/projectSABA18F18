# %%
import numpy as np
import pandas as pd
df=pd.read_csv("18F18saba.csv")

# %%
df
# Out:
#     Rank  Condition   id                     disease         type of disease  \
# 0      1   animal_1  11S             Avian Influenza          viral diseases
# 1      2   animal_2  22S           Rift Valley fever          viral diseases
# 2      3   animal_3  33S         Bovine tuberculosis       bacterial disease
# 3      4   animal_4  44S                 Lumpy skin           viral diseases
# 4      5   animal_5  55S  Peste des Petits Ruminants          viral diseases
# 5      6   animal_6  66S       Bovine viral diarrhea          viral diseases
# 6      7   animal_7  77S                   Newcastle          viral diseases
# 7      8   animal_8  88S           Infectious Coryza       bacterial disease
# 8      9   animal_9  99S          Necrotic enteritis       bacterial disease
# 9     10  animal_10  00S                    Ascarids      Parasitic diseases
# 10    11  animal_11  12S            Anthrax disease        bacterial disease
# ...

# %%
df.corr()
# Out:
#                      Rank  no.of symptoms  no.of medicines
# Rank             1.000000       -0.175667         0.569521
# no.of symptoms  -0.175667        1.000000        -0.018158
# no.of medicines  0.569521       -0.018158         1.000000

# %%
df.head()
# Out:
#    Rank Condition   id                     disease     type of disease  \
# 0     1  animal_1  11S             Avian Influenza      viral diseases
# 1     2  animal_2  22S           Rift Valley fever      viral diseases
# 2     3  animal_3  33S         Bovine tuberculosis   bacterial disease
# 3     4  animal_4  44S                 Lumpy skin       viral diseases
# 4     5  animal_5  55S  Peste des Petits Ruminants      viral diseases
#
#   type of animal risk rate                                           symptoms  \
# 0        poultry      high  Lack of Appetite_Swelled Eyes_Sneezing and Cou...
# 1      livestock      high   fever_failure to eat_weakness_diarrhea and death
# 2      livestock      high  dyspnea_increased body temperature_ sharp depl...
# 3      livestock      high  nodules around the head and neck and limbs _ma...
# 4      livestock      high  fever_ nasal discharge is serous_Diarrhea prof...
#
#    no.of symptoms                        pathogens  \
# ...

# %%
print(df.tail())
# Out:
#     Rank  Condition   id                    disease     type of disease  \
# 16    17  animal_17  18S                  Avian Pox      viral diseases
# 17    18  animal_18  19S  Equine encephalomyelitis       viral diseases
# 18    19  animal_19  20S    Hemorrhagic septicemia    bacterial disease
# 19    20  animal_20  30S                  Sheep Pox      viral diseases
# 20    21  animal_21  40S         Lameness in Cattle  Parasitic diseases
#
#    type of animal risk rate  \
# 16        poultry      high
# 17      livestock      high
# 18      livestock      high
# 19      livestock      high
# 20      livestock      high
#
#                                              symptoms  no.of symptoms  \
# 16  Scabs around eyes and mouth_Blue tint of skin_...              10
# 17  Fever_Listlessness_Loss of appetite_Irritation...               7
# 18  fever_Restlessness_Laziness while moving_Lacri...               6
# 19          fever_ macules_severe systemic infections               3
# ...

# %%
print(df)
# Out:
#     Rank  Condition   id                     disease         type of disease  \
# 0      1   animal_1  11S             Avian Influenza          viral diseases
# 1      2   animal_2  22S           Rift Valley fever          viral diseases
# 2      3   animal_3  33S         Bovine tuberculosis       bacterial disease
# 3      4   animal_4  44S                 Lumpy skin           viral diseases
# 4      5   animal_5  55S  Peste des Petits Ruminants          viral diseases
# 5      6   animal_6  66S       Bovine viral diarrhea          viral diseases
# 6      7   animal_7  77S                   Newcastle          viral diseases
# 7      8   animal_8  88S           Infectious Coryza       bacterial disease
# 8      9   animal_9  99S          Necrotic enteritis       bacterial disease
# 9     10  animal_10  00S                    Ascarids      Parasitic diseases
# 10    11  animal_11  12S            Anthrax disease        bacterial disease
# ...

# %%
#to draw the Plot using Heatmaps
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.title('Covariance Plot')
# Out:
# Text(0.5, 1.0, 'Covariance Plot')

# %%
df.shape
# Out:
# (21, 14)

# %%
df.keys()
# Out:
# Index(['Rank', 'Condition', 'id', 'disease', 'type of disease',
#        'type of animal', 'risk rate', 'symptoms', 'no.of symptoms',
#        'pathogens', 'prevention', 'treatment', 'appropriate medicines',
#        'no.of medicines'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                      int64
# Condition                object
# id                       object
# disease                  object
# type of disease          object
# type of animal           object
# risk rate                object
# symptoms                 object
# no.of symptoms            int64
# pathogens                object
# prevention               object
# treatment                object
# appropriate medicines    object
# no.of medicines           int64
# dtype: object

# %%
df.isnull()
# Out:
#      Rank  Condition     id  disease  type of disease  type of animal  \
# 0   False      False  False    False            False           False
# 1   False      False  False    False            False           False
# 2   False      False  False    False            False           False
# 3   False      False  False    False            False           False
# 4   False      False  False    False            False           False
# 5   False      False  False    False            False           False
# 6   False      False  False    False            False           False
# 7   False      False  False    False            False           False
# 8   False      False  False    False            False           False
# 9   False      False  False    False            False           False
# 10  False      False  False    False            False           False
# 11  False      False  False    False            False           False
# ...

# %%
df.describe()
# Out:
#             Rank  no.of symptoms  no.of medicines
# count  21.000000       21.000000        21.000000
# mean   11.000000        5.761905         2.047619
# std     6.204837        2.981690         1.627151
# min     1.000000        2.000000         0.000000
# 25%     6.000000        3.000000         1.000000
# 50%    11.000000        6.000000         2.000000
# 75%    16.000000        7.000000         3.000000
# max    21.000000       13.000000         5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   21 non-null     int64
#  1   Condition              21 non-null     object
#  2   id                     21 non-null     object
#  3   disease                21 non-null     object
#  4   type of disease        21 non-null     object
#  5   type of animal         21 non-null     object
#  6   risk rate              21 non-null     object
#  7   symptoms               21 non-null     object
#  8   no.of symptoms         21 non-null     int64
#  9   pathogens              21 non-null     object
#  10  prevention             21 non-null     object
#  11  treatment              19 non-null     object
#  12  appropriate medicines  16 non-null     object
#  13  no.of medicines        21 non-null     int64
# dtypes: int64(3), object(11)
# ...

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)
missing_percentages[missing_percentages != 0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn')
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), yticklabels = False, cmap = 'plasma')
plt.title('Null Values in Data Frame')
# Out:
# Text(0.5, 1.0, 'Null Values in Data Frame')

# %%
from sklearn.pipeline import Pipeline
sns.pairplot(df, hue='pathogens')
plt.show()

# %%
sns.pairplot(df, hue='type of disease')
plt.show()

# %%
df.dropna()
# Out:
#     Rank  Condition   id                    disease         type of disease  \
# 0      1   animal_1  11S            Avian Influenza          viral diseases
# 3      4   animal_4  44S                Lumpy skin           viral diseases
# 6      7   animal_7  77S                  Newcastle          viral diseases
# 7      8   animal_8  88S          Infectious Coryza       bacterial disease
# 8      9   animal_9  99S         Necrotic enteritis       bacterial disease
# 9     10  animal_10  00S                   Ascarids      Parasitic diseases
# 10    11  animal_11  12S           Anthrax disease        bacterial disease
# 11    12  animal_12  13S              Black Quarter       bacterial disease
# 12    13  animal_13  14S     Foot and Mouth Disease                 Genetic
# 13    14  animal_14  15S           Mastitis in cows  microorganisms disease
# 15    16  animal_16  17S                     Thrush          fungal disease
# ...

# %%
df.isnull().sum()
# Out:
# Rank                     0
# Condition                0
# id                       0
# disease                  0
# type of disease          0
# type of animal           0
# risk rate                0
# symptoms                 0
# no.of symptoms           0
# pathogens                0
# prevention               0
# treatment                2
# appropriate medicines    5
# no.of medicines          0
# dtype: int64

# %%
df.plot(kind = 'scatter', x = 'risk rate', y = 'type of disease')
plt.show()

# %%
from sklearn.utils import shuffle
train = shuffle(pd.read_csv("18F18saba.csv"))
test = shuffle(pd.read_csv("18F18saba.csv"))

# %%
print("Any missing sample in training set:",train.isnull().values.any())
print("Any missing sample in test set:",test.isnull().values.any(), "\n")
# Out:
# Any missing sample in training set: True
# Any missing sample in test set: True

# %%
#Frequency distribution of classes"
train_outcome = pd.crosstab(index=train["type of disease"],  # Make a crosstab
                              columns="count")      # Name the count column

train_outcome
# Out:
# col_0                   count
# type of disease
#  bacterial disease          6
# Genetic                     1
# Parasitic diseases          2
# Poisoning disease           1
# fungal disease              1
# microorganisms disease      1
# viral diseases              9

# %%
# Visualizing Outcome Distribution 
temp = train["disease"].value_counts()
df = pd.DataFrame({'labels': temp.index,
                   'values': temp.values
                  })

#df.plot(kind='pie',labels='labels',values='values', title='Activity Ditribution',subplots= "True")

labels = df['labels']
sizes = df['values']
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','cyan','lightpink']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90, pctdistance=1.1, labeldistance=1.2)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# Seperating Predictors and Outcome values from train and test sets
X_train = pd.DataFrame(train.drop(['disease','pathogens'],axis=1))
Y_train_label = train.disease.values.astype(object)
X_test = pd.DataFrame(test.drop(['disease','pathogens'],axis=1))
Y_test_label = test.disease.values.astype(object)

# Dimension of Train and Test set 
print("Dimension of Train set",X_train.shape)
print("Dimension of Test set",X_test.shape,"\n")

# Transforming non numerical labels into numerical labels
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()

# encoding train labels 
encoder.fit(Y_train_label)
Y_train = encoder.transform(Y_train_label)

# encoding test labels 
encoder.fit(Y_test_label)
Y_test = encoder.transform(Y_test_label)

#Total Number of Continous and Categorical features in the training set
num_cols = X_train._get_numeric_data().columns
print("Number of numeric features:",num_cols.size)
# Out:
# Dimension of Train set (21, 12)
# Dimension of Test set (21, 12)
#
# Number of numeric features: 3

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_features=20,
    n_classes=3,
    n_samples=210,
    n_informative=2,
    random_state=1,
    n_clusters_per_class=1,
)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=125
)

# %%
from sklearn.naive_bayes import GaussianNB
# Build a Gaussian Classifier
model = GaussianNB()

# Model training
model.fit(X_train, y_train)

# Predict Output
predicted = model.predict([X_test[9]])

print("Actual Value:", y_test[9])
print("Predicted Value:", predicted[0])

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
)


y_pred = model.predict(X_test)
accuray = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Actual Value: 1
# Predicted Value: 2
# Accuracy: 0.8714285714285714
# F1 Score: 0.8705314009661835

# %%
from sklearn.svm import SVC

svclassifier = SVC(kernel = 'linear')

# %%
import time

starting_time = time.time()
svclassifier.fit(X_train, y_train)
print("Trained model in %s ms " % str(time.time() - starting_time))
# Out:
# Trained model in 0.01430201530456543 ms

# %%
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import seaborn as sn

print(classification_report(y_test,y_pred))

acc = float(accuracy_score(y_test,y_pred))*100
print("----accuracy score %s ----" % acc)

cm = confusion_matrix(y_test,y_pred)
df_cm = pd.DataFrame(cm)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        20
#            1       0.59      0.73      0.65        22
#            2       0.87      0.71      0.78        28
#
#     accuracy                           0.74        70
#    macro avg       0.75      0.75      0.75        70
# weighted avg       0.76      0.74      0.75        70
#
# ----accuracy score 74.28571428571429 ----

# %%
train_acc = float(svclassifier.score(X_train, y_train)*100)
print("----train accuracy score %s ----" % train_acc)

test_acc = float(svclassifier.score(X_test, y_test)*100)
print("----test accuracy score %s ----" % test_acc)
# Out:
# ----train accuracy score 91.42857142857143 ----
# ----test accuracy score 74.28571428571429 ----

# %%
from sklearn.model_selection import cross_val_score

# no. of folds cv = 5
cv_results = cross_val_score(svclassifier, X, y, cv = 5)
print(cv_results)
# Out:
# [0.78571429 0.83333333 0.95238095 0.83333333 0.69047619]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC


#splitting dataset into train/ test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# Setup the pipeline steps: steps
steps = [('scaler', StandardScaler()),
        ('SVM', SVC())]
        
# Create the pipeline: pipeline
pipeline = Pipeline(steps)

# Fit the pipeline to the training set: svc_scaled
svc_scaled = pipeline.fit(X_train, y_train)

# Instantiate and fit a classifier to the unscaled data
svc_unscaled = SVC(kernel = 'linear').fit(X_train, y_train)

# Compute and print metrics
print('Accuracy with Scaling: {}'.format(svc_scaled.score(X_test, y_test)))
print('Accuracy without Scaling: {}'.format(svc_unscaled.score(X_test, y_test)))
# Out:
# Accuracy with Scaling: 0.8571428571428571
# Accuracy without Scaling: 0.8095238095238095

# %%
train_acc = float(svc_scaled.score(X_train, y_train)*100)
print("----train accuracy score %s ----" % train_acc)

test_acc = float(svc_scaled.score(X_test, y_test)*100)
print("----test accuracy score %s ----" % test_acc)
# Out:
# ----train accuracy score 94.64285714285714 ----
# ----test accuracy score 85.71428571428571 ----

# %%
scaled_predictions = svc_scaled.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import seaborn as sn

print(classification_report(y_test,scaled_predictions))

acc = float(accuracy_score(y_test,scaled_predictions))*100
print("----accuracy score %s ----" % acc)

cm = confusion_matrix(y_test,scaled_predictions)
df_cm = pd.DataFrame(cm)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        13
#            1       0.85      0.79      0.81        14
#            2       0.87      0.87      0.87        15
#
#     accuracy                           0.86        42
#    macro avg       0.86      0.86      0.86        42
# weighted avg       0.86      0.86      0.86        42
#
# ----accuracy score 85.71428571428571 ----

# %%
df=pd.read_csv("18F18saba.csv")
import matplotlib.pyplot as plt
# %matplotlib inline
  
plt.plot(df['disease'],color='red')
plt.plot(df['pathogens'],color='blue')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
  
plt.plot(df['type of animal'],color='red')
plt.plot(df['type of disease'],color='blue')

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))

# %%
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('SVM (Test set)')
plt.xlabel('disease')
plt.ylabel('risk rate')
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df
# Out:
#     Rank  Condition   id                     disease         type of disease  \
# 0      1   animal_1  11S             Avian Influenza          viral diseases
# 1      2   animal_2  22S           Rift Valley fever          viral diseases
# 2      3   animal_3  33S         Bovine tuberculosis       bacterial disease
# 3      4   animal_4  44S                 Lumpy skin           viral diseases
# 4      5   animal_5  55S  Peste des Petits Ruminants          viral diseases
# 5      6   animal_6  66S       Bovine viral diarrhea          viral diseases
# 6      7   animal_7  77S                   Newcastle          viral diseases
# 7      8   animal_8  88S           Infectious Coryza       bacterial disease
# 8      9   animal_9  99S          Necrotic enteritis       bacterial disease
# 9     10  animal_10  00S                    Ascarids      Parasitic diseases
# 10    11  animal_11  12S            Anthrax disease        bacterial disease
# ...
