# %%
import numpy as np
import pandas as pd
df=pd.read_csv("18F18saba.csv")

# %%
df
# Out:
#     Rank  Condition   id                     disease         type of disease  \
# 0      1   animal_1  11S             Avian Influenza          viral diseases
# 1      2   animal_2  22S           Rift Valley fever          viral diseases
# 2      3   animal_3  33S         Bovine tuberculosis       bacterial disease
# 3      4   animal_4  44S                 Lumpy skin           viral diseases
# 4      5   animal_5  55S  Peste des Petits Ruminants          viral diseases
# 5      6   animal_6  66S       Bovine viral diarrhea          viral diseases
# 6      7   animal_7  77S                   Newcastle          viral diseases
# 7      8   animal_8  88S           Infectious Coryza       bacterial disease
# 8      9   animal_9  99S          Necrotic enteritis       bacterial disease
# 9     10  animal_10  00S                    Ascarids      Parasitic diseases
# 10    11  animal_11  12S            Anthrax disease        bacterial disease
# ...

# %%
df.head()
# Out:
#    Rank Condition   id                     disease     type of disease  \
# 0     1  animal_1  11S             Avian Influenza      viral diseases
# 1     2  animal_2  22S           Rift Valley fever      viral diseases
# 2     3  animal_3  33S         Bovine tuberculosis   bacterial disease
# 3     4  animal_4  44S                 Lumpy skin       viral diseases
# 4     5  animal_5  55S  Peste des Petits Ruminants      viral diseases
#
#   type of animal risk rate                                           symptoms  \
# 0        poultry      high  Lack of Appetite_Swelled Eyes_Sneezing and Cou...
# 1      livestock      high   fever_failure to eat_weakness_diarrhea and death
# 2      livestock      high  dyspnea_increased body temperature_ sharp depl...
# 3      livestock      high  nodules around the head and neck and limbs _ma...
# 4      livestock      high  fever_ nasal discharge is serous_Diarrhea prof...
#
#    no.of symptoms                        pathogens  \
# ...

# %%
print(df.tail())
# Out:
#     Rank  Condition   id                    disease     type of disease  \
# 16    17  animal_17  18S                  Avian Pox      viral diseases
# 17    18  animal_18  19S  Equine encephalomyelitis       viral diseases
# 18    19  animal_19  20S    Hemorrhagic septicemia    bacterial disease
# 19    20  animal_20  30S                  Sheep Pox      viral diseases
# 20    21  animal_21  40S         Lameness in Cattle  Parasitic diseases
#
#    type of animal risk rate  \
# 16        poultry      high
# 17      livestock      high
# 18      livestock      high
# 19      livestock      high
# 20      livestock      high
#
#                                              symptoms  no.of symptoms  \
# 16  Scabs around eyes and mouth_Blue tint of skin_...              10
# 17  Fever_Listlessness_Loss of appetite_Irritation...               7
# 18  fever_Restlessness_Laziness while moving_Lacri...               6
# 19          fever_ macules_severe systemic infections               3
# ...

# %%
print(df)
# Out:
#     Rank  Condition   id                     disease         type of disease  \
# 0      1   animal_1  11S             Avian Influenza          viral diseases
# 1      2   animal_2  22S           Rift Valley fever          viral diseases
# 2      3   animal_3  33S         Bovine tuberculosis       bacterial disease
# 3      4   animal_4  44S                 Lumpy skin           viral diseases
# 4      5   animal_5  55S  Peste des Petits Ruminants          viral diseases
# 5      6   animal_6  66S       Bovine viral diarrhea          viral diseases
# 6      7   animal_7  77S                   Newcastle          viral diseases
# 7      8   animal_8  88S           Infectious Coryza       bacterial disease
# 8      9   animal_9  99S          Necrotic enteritis       bacterial disease
# 9     10  animal_10  00S                    Ascarids      Parasitic diseases
# 10    11  animal_11  12S            Anthrax disease        bacterial disease
# ...

# %%
import matplotlib.pyplot as plt
df.plot()
plt.show()

# %%
#Matplotlib Scatter
import matplotlib.pyplot as plt
import numpy as np

#disease and the type of animal disease:
x = np.array(['viral diseases','viral diseases','bacterial disease','viral diseases','viral diseases','viral diseases','viral diseases','bacterial disease','bacterial disease'])
y = np.array(['Avian Influenza','Rift Valley fever','Bovine tuberculosis','Lumpy skin ','Peste des Petits Ruminants','Bovine viral diarrhea','Newcastle','Infectious Coryza','Necrotic enteritis'])
plt.scatter(x, y)

#type of animal and risk rate:
x = np.array(['poultry','livestock','livestock','livestock','livestock','livestock','poultry','poultry','poultry'])
y = np.array(['high','high','high','high','high','high','high','high','high'
])
plt.scatter(x, y)

plt.show()

# %%
#to draw the Plot using Heatmaps
import seaborn as sns
sns.heatmap(df.corr())
plt.title('Covariance Plot')
# Out:
# Text(0.5, 1.0, 'Covariance Plot')

# %%
df.corr()
# Out:
#                      Rank  no.of symptoms  no.of medicines
# Rank             1.000000       -0.175667         0.569521
# no.of symptoms  -0.175667        1.000000        -0.018158
# no.of medicines  0.569521       -0.018158         1.000000

# %%
df.dtypes
# Out:
# Rank                      int64
# Condition                object
# id                       object
# disease                  object
# type of disease          object
# type of animal           object
# risk rate                object
# symptoms                 object
# no.of symptoms            int64
# pathogens                object
# prevention               object
# treatment                object
# appropriate medicines    object
# no.of medicines           int64
# dtype: object

# %%
df.isnull()
# Out:
#      Rank  Condition     id  disease  type of disease  type of animal  \
# 0   False      False  False    False            False           False
# 1   False      False  False    False            False           False
# 2   False      False  False    False            False           False
# 3   False      False  False    False            False           False
# 4   False      False  False    False            False           False
# 5   False      False  False    False            False           False
# 6   False      False  False    False            False           False
# 7   False      False  False    False            False           False
# 8   False      False  False    False            False           False
# 9   False      False  False    False            False           False
# 10  False      False  False    False            False           False
# 11  False      False  False    False            False           False
# ...

# %%
df.sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6880\1703867807.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# Rank                                                             231
# Condition          animal_1animal_2animal_3animal_4animal_5animal...
# id                 11S22S33S44S55S66S77S88S99S00S12S13S14S15S16S1...
# disease            Avian InfluenzaRift Valley feverBovine tubercu...
# type of disease    viral diseasesviral diseases bacterial disease...
# type of animal     poultrylivestocklivestocklivestocklivestockliv...
# risk rate          highhighhighhighhighhighhighhighhighhighhighhi...
# symptoms           Lack of Appetite_Swelled Eyes_Sneezing and Cou...
# no.of symptoms                                                   121
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Condition', 'id', 'disease', 'type of disease',
#        'type of animal', 'risk rate', 'symptoms', 'no.of symptoms',
#        'pathogens', 'prevention', 'treatment', 'appropriate medicines',
#        'no.of medicines'],
#       dtype='object')

# %%
df.shape
# Out:
# (21, 14)

# %%
df['total score'] = df['disease']+ df['pathogens']
df.head()
# Out:
#    Rank Condition   id                     disease     type of disease  \
# 0     1  animal_1  11S             Avian Influenza      viral diseases
# 1     2  animal_2  22S           Rift Valley fever      viral diseases
# 2     3  animal_3  33S         Bovine tuberculosis   bacterial disease
# 3     4  animal_4  44S                 Lumpy skin       viral diseases
# 4     5  animal_5  55S  Peste des Petits Ruminants      viral diseases
#
#   type of animal risk rate                                           symptoms  \
# 0        poultry      high  Lack of Appetite_Swelled Eyes_Sneezing and Cou...
# 1      livestock      high   fever_failure to eat_weakness_diarrhea and death
# 2      livestock      high  dyspnea_increased body temperature_ sharp depl...
# 3      livestock      high  nodules around the head and neck and limbs _ma...
# 4      livestock      high  fever_ nasal discharge is serous_Diarrhea prof...
#
#    no.of symptoms                        pathogens  \
# ...

# %%
df.plot(kind = 'scatter', x = 'type of animal', y = 'type of disease')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   21 non-null     int64
#  1   Condition              21 non-null     object
#  2   id                     21 non-null     object
#  3   disease                21 non-null     object
#  4   type of disease        21 non-null     object
#  5   type of animal         21 non-null     object
#  6   risk rate              21 non-null     object
#  7   symptoms               21 non-null     object
#  8   no.of symptoms         21 non-null     int64
#  9   pathogens              21 non-null     object
#  10  prevention             21 non-null     object
#  11  treatment              19 non-null     object
#  12  appropriate medicines  16 non-null     object
#  13  no.of medicines        21 non-null     int64
# ...

# %%
df.dropna()
# Out:
#     Rank  Condition   id                    disease         type of disease  \
# 0      1   animal_1  11S            Avian Influenza          viral diseases
# 3      4   animal_4  44S                Lumpy skin           viral diseases
# 6      7   animal_7  77S                  Newcastle          viral diseases
# 7      8   animal_8  88S          Infectious Coryza       bacterial disease
# 8      9   animal_9  99S         Necrotic enteritis       bacterial disease
# 9     10  animal_10  00S                   Ascarids      Parasitic diseases
# 10    11  animal_11  12S           Anthrax disease        bacterial disease
# 11    12  animal_12  13S              Black Quarter       bacterial disease
# 12    13  animal_13  14S     Foot and Mouth Disease                 Genetic
# 13    14  animal_14  15S           Mastitis in cows  microorganisms disease
# 15    16  animal_16  17S                     Thrush          fungal disease
# ...

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_features=20,
    n_classes=3,
    n_samples=210,
    n_informative=2,
    random_state=1,
    n_clusters_per_class=1,
)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=125
)

# %%
from sklearn.naive_bayes import GaussianNB
# Build a Gaussian Classifier
model = GaussianNB()

# Model training
model.fit(X_train, y_train)

# Predict Output
predicted = model.predict([X_test[9]])

print("Actual Value:", y_test[9])
print("Predicted Value:", predicted[0])
# Out:
# Actual Value: 1
# Predicted Value: 2

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
)

y_pred = model.predict(X_test)
accuray = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.8714285714285714
# F1 Score: 0.8705314009661835

# %%
labels = [0,1,2]
cm = confusion_matrix(y_test, y_pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df,x='disease',hue='type of disease')
plt.xticks(rotation=45, ha='right');

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df,x='type of disease',hue='type of animal')
plt.xticks(rotation=45, ha='right');

# %%
pre_df = pd.get_dummies(df,columns=['type of disease'],drop_first=True)
pre_df.head()
# Out:
#    Rank Condition   id                     disease type of animal risk rate  \
# 0     1  animal_1  11S             Avian Influenza        poultry      high
# 1     2  animal_2  22S           Rift Valley fever      livestock      high
# 2     3  animal_3  33S         Bovine tuberculosis      livestock      high
# 3     4  animal_4  44S                 Lumpy skin       livestock      high
# 4     5  animal_5  55S  Peste des Petits Ruminants      livestock      high
#
#                                             symptoms  no.of symptoms  \
# 0  Lack of Appetite_Swelled Eyes_Sneezing and Cou...               7
# 1   fever_failure to eat_weakness_diarrhea and death               5
# 2  dyspnea_increased body temperature_ sharp depl...              13
# 3  nodules around the head and neck and limbs _ma...               6
# 4  fever_ nasal discharge is serous_Diarrhea prof...               5
#
#                          pathogens  \
# 0                            virus
# ...

# %%
#to draw the Plot using Heatmaps
import seaborn as sns
sns.heatmap(df.corr())
plt.title('Covariance Plot')
# Out:
# Text(0.5, 1.0, 'Covariance Plot')
